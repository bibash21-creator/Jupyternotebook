# %% [markdown]
# # Example of Decision Tree

# %%
# Importing libraries

import pandas as pd

from sklearn.model_selection import train_test_split

from sklearn.tree import DecisionTreeClassifier

import  matplotlib.pyplot as plt

# %%
# Importing the file

wfile = pd.read_csv("wheatseeds.csv")
wfile.head()
# Out:
#     Area  Perimeter  Compactness  Kernel.Length  Kernel.Width  \
# 0  15.26      14.84       0.8710          5.763         3.312
# 1  14.88      14.57       0.8811          5.554         3.333
# 2  14.29      14.09       0.9050          5.291         3.337
# 3  13.84      13.94       0.8955          5.324         3.379
# 4  16.14      14.99       0.9034          5.658         3.562
#
#    Asymmetry.Coeff  Kernel.Groove  Type
# 0            2.221          5.220     1
# 1            1.018          4.956     1
# 2            2.699          4.825     1
# 3            2.259          4.805     1
# 4            1.355          5.175     1

# %%
# Separating the features

x = wfile.drop(['Area', 'Perimeter'], axis=1)
y = wfile.Type

# %%
# Training the data set

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size= 0.2, random_state= 42)

# %%
x_train.head()
# Out:
#      Compactness  Kernel.Length  Kernel.Width  Asymmetry.Coeff  Kernel.Groove  \
# 183       0.8795          5.132         2.953            3.597          5.132
# 38        0.8871          5.348         3.156            2.587          5.178
# 24        0.8849          5.833         3.421            0.903          5.307
# 142       0.8491          5.386         2.911            3.260          5.316
# 141       0.8658          5.267         2.967            4.421          5.002
#
#      Type
# 183     3
# 38      1
# 24      1
# 142     3
# 141     3

# %%
y_train.head()
# Out:
# 183    3
# 38     1
# 24     1
# 142    3
# 141    3
# Name: Type, dtype: int64

# %%
# Fitting the model

w_model = DecisionTreeClassifier(
)

w_model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# Predicting the outcomes

ypredict = w_model.predict([[5,2,3,5,6,7]])
ypredict
# Out:
# C:\Users\hp\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([3])

# %%
y.unique()
# Out:
# array([1, 2, 3])

# %%
y.unique().astype(str)
# Out:
# array(['1', '2', '3'], dtype='<U21')

# %%
labels = y.unique().astype(str)
labels
# Out:
# array(['1', '2', '3'], dtype='<U21')

# %%
# Making the decision tree

from sklearn.tree import plot_tree


plot_tree(w_model, feature_names=x.columns, class_names=labels, filled=True)
plt.show()
